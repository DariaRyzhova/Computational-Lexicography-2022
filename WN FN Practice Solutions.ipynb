# %% [markdown]
# # WordNet

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ДР\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn

# %% [markdown]
# ### Задание 1
#
# Cоставьте с помощью WordNet список существительных, которые могут выступать в качестве прямого дополнения при глаголе eat в предложениях вида John eats N (через поиск общего гиперонима для слов meat и potatos).

# %% [markdown]
# Сначала проверяем, к каким синсетам относятся слова meat и potatos, и выбираем нужные. Для этого смотрим на определения:

# %%
for synset in wn.synsets('meat', pos=wn.NOUN):
    print (synset.name(), synset.definition())
# Out:
# meat.n.01 the flesh of animals (including fishes and birds and snails) used as food
# kernel.n.01 the inner and usually edible part of a seed or grain or nut or fruit stone
# kernel.n.03 the choicest or most essential or most vital part of some idea or experience

# %%
for synset in wn.synsets('potatos', pos=wn.NOUN):
    print (synset.name(), synset.definition())
# Out:
# potato.n.01 an edible tuber native to South America; a staple food of Ireland
# potato.n.02 annual native to South America having underground stolons bearing edible starchy tubers; widely cultivated as a garden vegetable; vines are poisonous

# %% [markdown]
# Нам подходят meat.n.01 и potato.n.01, дальше работаем с ними: ищем их ближайший общий гипероним, а потом берем леммы из всех синсетов, которые являются его гипонимами.

# %%
print(wn.synset('meat.n.01').lowest_common_hypernyms(wn.synset('potato.n.01')))
# Out:
# [Synset('food.n.02')]

# %%
hypo = lambda s: s.hyponyms()
food_lemmas = set()
for synset in wn.synset('food.n.02').closure(hypo):
    for lemma in synset.lemma_names():
        food_lemmas.add(lemma)

for item in food_lemmas:
    print(item)
# Out:
# seafood
# kiwi
# Jerusalem_artichoke
# spinach_beet
# panfish
# quahog
# chou
# bitter_orange
# nonpareil
# rockfish
# ananas
# Valencia_orange
# dumpling
# buffalofish
# salad_green
# hard_roll
# Yellow_Delicious
# zucchini
# muskmelon
# loaf_of_bread
# Swiss_chard
# fish
# beurre_noisette
# white_cake
# calf's_liver
# junk_food
# hamburger_roll
# farm_cheese
# spice_cake
# beet_green
# salt-rising_bread
# tunny
# french-fried_potatoes
# tamarindo
# rose_apple
# scrag
# water_lemon
# aitchbone
# salt_cod
# pandowdy
# sinker
# netted_melon
# chocolate_bar
# finnan_haddock
# chop
# boxberry
# finnan
# chine
# Jewish_rye
# lime
# pasta
# huckleberry
# Bibb_lettuce
# bean
# mascarpone
# turban_squash
# chuck
# smoked_eel
# zwieback
# tuna_fish
# minute_steak
# tortilla
# mandarin
# blintz
# strudel
# matzah_ball
# ugli
# yellow_turnip
# wonton
# spareribs
# hen
# rosefish
# stomach_sweetbread
# giblet
# caviare
# bully_beef
# rainbow_trout
# citron
# mustard_greens
# swordfish
# lichi
# triple_creme
# rump_steak
# pork_pie
# red_onion
# sieva_bean
# dika_bread
# coral
# blue_point
# langoustine
# profiterole
# cuke
# green_soybean
# cabbage
# unleavened_bread
# honey_bun
# sloe
# Chinese_jujube
# swede
# bacon
# annon
# luncheon_meat
# Persian_melon
# double_cream
# quick_bread
# Twinkie
# largemouth_bass
# Bologna_sausage
# Tokay
# whiting
# scrod
# breakfast_food
# lingcod
# jaboticaba
# chopsteak
# clarified_butter
# cross_bun
# Alaska_king_crab
# turnip_cabbage
# American_lobster
# fillet_of_sole
# greengage
# sapota
# brown_butter
# pear
# pork_tenderloin
# muesli
# common_bean
# rusk
# turnip_greens
# saskatoon
# dandelion_green
# nectarine
# limpet
# raspberry
# cos
# fettuccini
# ribier
# acorn_squash
# caviar
# rib_roast
# clementine
# plum
# Swedish_rye
# Nova_Scotia_salmon
# cut_of_meat
# halibut
# papaya
# sparerib
# fruit_bar
# Victoria_plum
# gumbo
# lobster
# sweet_melon
# bittersweet_chocolate
# spaghetti_squash
# Cornish_pasty
# European_lobster
# weakfish
# soursop
# potherb
# semi-sweet_chocolate
# crouton
# beef_neck
# banana_bread
# mudcat
# spaghetti
# club_steak
# red_snapper
# Cortland
# avocado_pear
# flapcake
# beetroot
# crab_apple
# lobster_tail
# tagliatelle
# giblets
# kitambilla
# shrimp
# fritter
# pomegranate
# codfish
# leg_of_lamb
# Pippin
# shank
# brandysnap
# summer_squash
# split-pea
# loganberry
# slop
# raisin_cookie
# perch
# persimmon
# pilot_bread
# smoked_haddock
# marrowfat_pea
# eel
# sponge_cake
# mangel-wurzel
# garlic_bread
# kidney_pie
# chipotle
# hoecake
# ship_biscuit
# cajan_pea
# wild_spinach
# blintze
# green_pea
# partridge
# damson_plum
# gnocchi
# kale
# ginger_nut
# brook_trout
# temple_orange
# rhubarb
# cinnamon_bread
# checkerberry
# doughnut
# Paschal_celery
# process_cheese
# red_cabbage
# grits
# rack
# river_prawn
# frumenty
# offal
# goose_liver
# Stayman_Winesap
# fugu
# coho
# corn_dab
# honeydew_melon
# frankfurter
# Parker_House_roll
# tabasco
# Winesap
# wafer
# sirloin
# biscuit
# fry_bread
# cheese
# Jewish_rye_bread
# watermelon
# honeycomb_tripe
# salmon
# anchovy_pear
# flannel_cake
# gem
# teacake
# turbot
# monstera
# halal
# buckwheat_cake
# wax_bean
# Parmesan
# spud
# refrigerator_cookie
# shortbread_cookie
# French_loaf
# flank_steak
# canistel
# frank
# bannock
# alligator_pear
# skillet_cake
# lichee
# prosciutto
# sticky_bun
# french_fries
# Nova_lox
# Bramley's_Seedling
# plaice
# rambutan
# Christmas_cake
# white_bread
# jalapeno
# grissino
# pimento
# cottage_cheese
# jujube
# brisling
# green_bean
# lingonberry
# broccoli
# murphy
# buffalo
# jak
# round
# garambulla
# beef_jerky
# carissa_plum
# leftovers
# side_of_beef
# ratafia_biscuit
# pumpernickel
# key_lime
# chuck_short_ribs
# pepperoni
# wintergreen
# leg
# Empire
# long-neck_clam
# almond_cookie
# runner_bean
# lansa
# blade_apple
# duck
# oreo_cookie
# leechee
# angel_cake
# dried_fruit
# gluten_bread
# tangelo
# prune_cake
# tea_bread
# genipap
# akee
# ham_hock
# Nova_salmon
# corn_tash
# casaba_melon
# avocado
# coho_salmon
# granola
# European_blueberry
# weenie
# witloof
# hallah
# salmon_trout
# liverwurst
# monkey_bread
# scone
# liver_pudding
# milk_chocolate
# streusel
# Roquefort
# field_soybean
# whole_wheat_bread
# muscatel
# Atlantic_salmon
# pepper
# pulassan
# quark_cheese
# pulse
# tripe
# squab
# Northern_lobster
# savoy
# blueberry_pie
# Uruguay_potato
# green_groceries
# sugar_pea
# Host
# grey_sole
# blue_crab
# tenderloin
# patty_shell
# beefsteak
# swedish_turnip
# scallion
# dog_biscuit
# rolled_biscuit
# game
# escarole
# date_bar
# baking_chocolate
# courgette
# yak_butter
# brown_bread
# potato
# toad-in-the-hole
# atole
# joint
# Norwegian_lobster
# graham_bread
# barmbrack
# flame_tokay
# water_biscuit
# crabapple
# citrus
# danish
# frijole
# ashcake
# scuppernong
# bluepoint
# raisin_bran
# greens
# mince_pie
# fresh_foods
# shadberry
# applesauce_cake
# lemon
# butter_bean
# string_cheese
# flannel-cake
# corn_flake
# fettuccine_Alfredo
# whitebait
# croissant
# edible_fruit
# flat_bone
# Chinese_celery
# crawfish
# wedding_cake
# wheatflake
# kasha
# bream
# raisin
# Granny_Smith
# Boston_brown_bread
# sockeye
# blue_cheese
# shoofly_pie
# French_sorrel
# Newtown_Wonder
# butterbean
# cinnamon_bun
# brick_cheese
# pollack
# cantaloup
# cisco
# Gruyere
# turkey
# winter_melon
# tuna
# linguini
# crayfish
# lanset
# Scotch_pancake
# sirloin_steak
# edda
# brioche
# spice_cookie
# pork_roast
# lettuce
# crumpet
# gingerbread
# apple_tart
# staff_of_life
# lasagna
# shin_bone
# calf's_tongue
# collards
# Oven_Stuffer
# Brie
# bluefish
# cinnamon_toast
# marmalade_plum
# bok_choi
# river_pear
# noodle
# orzo
# bonito
# stick
# English_runner_bean
# pot_roast
# pomelo
# rhubarb_pie
# yellow_granadilla
# farfalle
# breadfruit
# ginger_snap
# Florence_fennel
# Irish_potato
# ziti
# buttermilk_biscuit
# lemonade_mix
# meat
# danish_pastry
# saddle_of_lamb
# bowtie_pasta
# hardtack
# tomalley
# native_peach
# processed_cheese
# capulin
# littleneck
# hard_roe
# chitterlings
# neck_sweetbread
# quiche
# crappie
# ceriman
# emperor
# muscadine
# pond_apple
# Liederkranz
# garden_cress
# juneberry
# taro
# latke
# gingersnap
# bird
# cusk
# TV_dinner
# clingstone
# freshwater_fish
# jelly_doughnut
# litchee
# puffer
# Thompson_Seedless
# Chinese_gooseberry
# leafy_vegetable
# sweetsop
# Red_Delicious
# timbale
# blowfish
# calves'_liver
# sour_bread
# cranberry
# Stilton
# pie_crust
# teaberry
# marrow
# crumb_cake
# cherimolla
# blackheart
# onion_bread
# layer_cake
# cut_of_veal
# jalapeno_pepper
# rabbit
# ham
# bluefin_tuna
# bacon_strip
# pumpkin_pie
# round_clam
# plate
# roast_lamb
# sapote
# beluga_caviar
# Japanese_crab
# caraway_seed_bread
# Pearmain
# mangosteen
# baked_potato
# Canadian_bacon
# albacore
# husk_tomato
# yoghurt
# salami
# seed_cake
# flank
# sweet_cherry
# pastrami
# torte
# lentil
# roast_veal
# cornmeal_mush
# napoleon
# loquat
# sultana
# rigatoni
# Edam
# snapper
# Gouda_cheese
# garden_pea
# pieplant
# sweet_pepper
# cooking_apple
# Vidalia_onion
# penne
# chilly
# scrapple
# winkle
# hot_dog
# saveloy
# ilama
# upside-down_cake
# won_ton
# croaker
# onion
# honeydew
# convenience_food
# black_pudding
# tournedos
# manicotti
# mahimahi
# side
# muskellunge
# frankfurter_bun
# chile
# bok_choy
# endive
# smoked_salmon
# cut_of_pork
# hominy_grits
# litchi
# pocket_bread
# haricot
# roast_pork
# foreshank
# guanabana
# apple_pie
# Jamaica_apple
# schnecken
# fresh_bean
# caramel_bun
# cayenne
# seckel
# waffle
# jackfruit
# meat_loaf
# cookie
# pea
# hotdog
# sea_squab
# rock_salmon
# bartlett_pear
# green_pepper
# beef_patty
# gooseberry
# iceberg
# sweetbread
# Northern_Spy
# rutabaga
# pollock
# red_salmon
# chicory
# flapjack
# passion_fruit
# oatmeal_cookie
# flatfish
# smoked_herring
# romaine_lettuce
# home-fried_potatoes
# spatchcock
# prickly_pear
# anjou
# oyster
# pea_bean
# cold_cereal
# broccoli_rabe
# sweet_cup
# Barbados_gooseberry
# knockwurst
# flounder
# mad_apple
# bartlett
# quandong
# loaf
# throat_sweetbread
# ketembilla
# bridecake
# elver
# French_fritter
# jerk
# matzoh
# bullace_grape
# batter_bread
# gherkin
# lobster_tart
# soy
# dog
# salad_burnet
# limpa
# spoon_bread
# hake
# cocoa_plum
# date_bread
# radicchio
# Meuniere_butter
# stone_crab
# orange_toast
# Boston_cream_pie
# bluefin
# bamboo_shoot
# melon
# skillet_corn_bread
# black_salsify
# bottom_round
# Bavarian_blue
# shad
# kitembilla
# shaddock
# skillet_bread
# Belgian_waffle
# dry_cereal
# brat
# calamari
# hard-shell_clam
# green_onion
# radish
# Victoria_sponge
# chocolate_eclair
# Maine_lobster
# stockfish
# takeaway
# takeout_food
# baklava
# mussel
# anadama_bread
# papaw
# knackwurst
# sugar_snap_pea
# boysenberry
# savarin
# sausage
# shortbread
# fruitcake
# Catawba
# loin_of_lamb
# Victoria_sandwich
# poulet
# drop_biscuit
# pecan_pie
# prune
# rambotan
# Madeira_sponge
# king_crab
# Spanish_lime
# corn_cake
# coffee_cake
# scallop
# string_bean
# red_pepper
# liver
# hindshank
# berry
# liver_sausage
# pancake
# store_cheese
# truffle
# sweetbreads
# cucumber
# grapefruit
# bread-stick
# apricot_bar
# seedless_raisin
# entrecote
# soft_roe
# chocolate_chip_cookie
# hot_cereal
# navel_orange
# pot_cheese
# crookneck
# beef_tenderloin
# ghee
# huitre
# linguica
# Cheshire_cheese
# celery
# rollmops
# kidney_bean
# cruciferous_vegetable
# barbados_cherry
# roast
# spiny_lobster
# ready-mix
# stew_meat
# milt
# leaf_lettuce
# buttermilk_pancake
# Velveeta
# tomatillo
# chili_pepper
# brisket
# Indian_mustard
# chop-suey_greens
# oreo
# cod
# eating_apple
# cockle
# lychee
# dark_meat
# sugar_apple
# steamer
# casaba
# tart
# mountain_cranberry
# bran_flake
# pita
# confit
# date
# sea_biscuit
# cushaw
# black_currant
# cochon_de_lait
# rack_of_lamb
# flatbrod
# top_round
# broiler
# striped_bass
# white_bean
# hand_cheese
# Dutch-processed_cocoa
# chickpea
# snap
# litchi_nut
# sailfish
# speckled_trout
# snail
# Bermuda_onion
# cooky
# sugar_cookie
# Emmental
# Swedish_rye_bread
# Pablum
# lasagne
# rainbow_smelt
# gigot
# hog_plum
# raw_vegetable
# bean_sprout
# scarlet_runner_bean
# mashed_potato
# blueberry_yogurt
# medlar
# ecrevisse
# McIntosh
# whelk
# rock_lobster
# Rock_Cornish_hen
# fries
# crepe_Suzette
# Grimes'_golden
# citrus_fruit
# catfish
# grated_cheese
# oxheart_cherry
# cracker
# graham_cracker
# white_potato
# triple_cream
# genoise
# sausage_meat
# lemon_meringue_pie
# bullock's_heart
# mostaccioli
# mushroom
# artichoke
# mammee_apple
# baba
# pitahaya
# venison
# home_fries
# navy_bean
# collard_greens
# lanseh
# neck
# curly_endive
# Mexican_husk_tomato
# wiener
# petit_four
# bratwurst
# strip_steak
# cupcake
# lunch_meat
# dolphinfish
# ash_cake
# cowpea
# lambchop
# sourdough_bread
# West_Indian_cherry
# crawdad
# bosc
# tostada
# yellow_mombin
# coffeecake
# earthnut
# chocolate_candy
# corn_fritter
# green
# eggfruit
# bloater
# chevre
# scarlet_runner
# coconut_cake
# yellow_squash
# porterhouse
# leek
# shell_bean
# soybean
# American_smelt
# feijoa
# pigweed
# dewberry
# horseflesh
# winter_cress
# salt_pork
# Chinese_date
# black_bean
# biltong
# octopus
# corn_beef
# black_bread
# plantain
# whitefish
# banger
# veal_roast
# simnel
# Golden_Delicious
# net_melon
# cake_mix
# yellow_bean
# duckling
# fava_bean
# pemican
# challah
# red_rockfish
# soft-shelled_crab
# pickerel
# johnnycake
# calves'_feet
# Belgian_endive
# vegetable
# ruggelach
# vinifera_grape
# pattypan_squash
# baguette
# gobbet
# egg_noodle
# cling
# vol-au-vent
# smelt
# Hershey_bar
# timbale_case
# sour_orange
# frier
# bran_muffin
# picnic_shoulder
# chicory_escarole
# hasty_pudding
# cole
# pilot_biscuit
# friedcake
# icaco
# donut
# cinnamon_snail
# chinook_salmon
# honey_cake
# edible_bean
# breadstick
# soda_biscuit
# parsnip
# damson
# chili
# anchovy
# heart_cherry
# French_pastry
# littleneck_clam
# pigeon_pea
# corn_dodger
# nan
# coconut
# mulberry
# cauliflower
# tartlet
# kumquat
# hot_cross_bun
# baking-powder_biscuit
# ugli_fruit
# kaiser_roll
# hushpuppy
# smallmouth_bass
# mutton
# sweet_potato
# ocean_perch
# whortleberry
# date-nut_bread
# bear_paw
# Oven_Stuffer_Roaster
# haslet
# sapsago
# bologna
# tortellini
# pound_cake
# cold_cuts
# celery_root
# finocchio
# matzo_ball
# kiwi_fruit
# Rome_Beauty
# Lane's_Prince_Albert
# pilchard
# steak
# yellowtail_flounder
# pork_loin
# meat_pie
# cake
# gammon
# raisin_bread
# doughboy
# coconut_meat
# marble_cake
# celeriac
# escargot
# undercut
# cream_puff
# pin_bone
# English_muffin
# apple
# Boston_lettuce
# yam
# puff
# muscat
# Brussels_biscuit
# root_vegetable
# jambon
# kiss
# common_sorrel
# Seville_orange
# butternut_squash
# cheddar_cheese
# bay_scallop
# loin
# goat_cheese
# roe
# chocolate_kiss
# birthday_cake
# T-bone_steak
# porterhouse_steak
# kohlrabi
# volaille
# romaine
# tourtiere
# acerola
# muffin
# cheesecake
# patty
# naan
# beefsteak_tomato
# apple_fritter
# seeded_raisin
# prawn
# saddle
# fettuccine
# flatbread
# tea_biscuit
# hamburger_steak
# alewife
# Virginia_ham
# rump
# escallop
# cracked-wheat_bread
# bass
# Italian_bread
# crabmeat
# rum_baba
# baked_goods
# roast_beef
# Alaskan_king_crab
# blade_roast
# solanaceous_vegetable
# banana
# sprout
# seckel_pear
# salsify
# cocoa_powder
# breast_of_lamb
# porc
# kai_apple
# chilli
# windfall
# pulasan
# chapati
# taro_root
# cobbler
# New_York_strip
# macaroni
# pemmican
# breadstuff
# citrange
# cream_cheese
# squash_pie
# white_turnip
# baguet
# sapodilla
# blackberry
# winter_flounder
# French_pancake
# granadilla
# chiffon_cake
# oysters_Rockefeller
# bear_claw
# gorgonzola
# blade
# pie_shell
# mullet
# pufferfish
# alimentary_paste
# French_bread
# summer_crookneck
# goa_bean
# nutmeg_melon
# jack
# mozzarella
# blini
# pompano
# mackerel
# sprat
# oyster_plant
# hamburger
# Stayman
# mouton
# breast_of_veal
# hot_cake
# silver_salmon
# Danish_blue
# mango
# Cox's_Orange_Pippin
# dried_apricot
# orange
# blood_sausage
# soft_pretzel
# chipolata
# muscat_grape
# sausage_roll
# cherimoya
# Emmenthaler
# chocolate
# sour_gourd
# variety_meat
# crown_roast
# couscous
# Armerican_cheddar
# sour_cherry
# vegetable_marrow
# crescent_roll
# bialy
# brussels_sprouts
# Vienna_roll
# grouper
# pone
# raw_meat
# steak_and_kidney_pie
# roaster
# onion_bagel
# Vienna_sausage
# fresh_food
# shallot
# hot_pepper
# bing_cherry
# currant
# buttercup_squash
# pawpaw
# Delicious
# bilberry
# puffed_wheat
# green_goods
# journey_cake
# cinnamon_roll
# dark_chocolate
# marang
# pfannkuchen
# hotdog_bun
# sugarberry
# Scandinavian_lox
# purple_onion
# jumbal
# pretzel
# chocolate_cake
# beignet
# brain
# scampo
# deep-dish_pie
# crookneck_squash
# finnan_haddie
# jimmies
# butterfish
# toast
# sapodilla_plum
# bialystoker
# fish_loaf
# sand_dab
# sweet_calabash
# cocoa_butter
# head_cabbage
# horsemeat
# tomato
# sorb_apple
# cornpone
# pimiento
# field_pea
# European_smelt
# lake_herring
# soft_roll
# shepherd's_pie
# pumpkin
# spaghettini
# carambola
# oatcake
# French_bean
# morello
# pike
# bleu
# tangerine
# hare
# filet_mignon
# chinook
# serviceberry
# gateau
# lamb-chop
# cocoyam
# sorb
# bitter_chocolate
# Emmentaler
# peach
# chard
# porgy
# double_Gloucester
# sunfish
# frangipane
# Yorkshire_pudding
# beef_loin
# cut_of_lamb
# cheddar
# hotcake
# kipper
# spiceberry
# beef_tongue
# wedge_bone
# cherry_tomato
# quahaug
# dragon's_eye
# boeuf
# chitlings
# cut
# globe_artichoke
# matzoh_ball
# Eccles_cake
# lemon_butter
# rugulah
# wildfowl
# soya
# copra
# dessert_apple
# chocolate_liquor
# rat_cheese
# cappelletti
# shad_roe
# almond_crescent
# fox_grape
# pigs'_knuckles
# scup
# rye_bread
# hindquarter
# red_herring
# sparling
# Chateaubriand
# filet
# standing_rib_roast
# flitch
# mustard
# polenta
# genipap_fruit
# ladyfinger
# melon_ball
# produce
# pastry
# longanberry
# iceberg_lettuce
# bouchee
# steamer_clam
# round_steak
# English_sole
# raised_doughnut
# cress
# dove
# fig
# dumplings
# plumcot
# linguine
# sole
# Nova_style_salmon
# raisin-nut_cookie
# garden_truck
# sucker
# yoghourt
# calamary
# chicken_liver
# elderberry
# pigs'_feet
# quandang
# veggie
# carrot
# porkchop
# flageolet
# shoulder
# custard_apple
# goose
# fryer
# vermicelli
# lamb
# Shawnee_cake
# legume
# potato_pancake
# mammee
# crab_legs
# crape
# Jaffa_orange
# vegetable_oyster
# satsuma
# bagel
# capon
# roll
# cereal
# redfish
# drawn_butter
# eater
# hamburger_bun
# snap_bean
# dark_bread
# whole_meal_bread
# corned_beef
# beef_roast
# fricandeau
# bismark
# Alaska_crab
# delicatessen
# cut_of_mutton
# spinach
# macaroon
# saltwater_fish
# sowbelly
# seedcake
# ricotta
# haricot_vert
# shortcake
# celtuce
# fedelline
# nut_bread
# black-eyed_pea
# veal
# tongue
# squash
# cantaloupe
# chopped_steak
# polony
# lemon_sole
# genip
# blackheart_cherry
# cocozelle
# lamb's-quarter
# butterhead_lettuce
# mombin
# kail
# crab
# leaf_beet
# eclair
# Madeira_cake
# side_of_bacon
# oxheart
# dahl
# poultry
# heart
# sea_scallop
# salmon_loaf
# soft-shell_crab
# salad_greens
# Swiss_cheese
# garbanzo
# rock_cake
# tater
# sirloin_tip
# pascal_celery
# guava
# dasheen
# beach_plum
# sugar_loaf
# slipskin_grape
# lansat
# Chinese_cabbage
# Nova_Scotia_lox
# onion_roll
# Kentucky_wonder
# Swiss_roll
# saltine
# veau
# wienerwurst
# bap
# civet_bean
# mush
# quiche_Lorraine
# Concord_grape
# chitlins
# star_fruit
# couverture
# matzah
# devil's_food_cake
# delicatessen_food
# freestone
# clover-leaf_roll
# sockeye_salmon
# picnic_ham
# Baldwin
# quantong
# fatback
# lake_trout
# johnny_cake
# yogurt
# asparagus
# lima_bean
# suckling_pig
# scorzonera
# sea_bass
# grape
# angel_food_cake
# Gouda
# Melba_toast
# turnip
# sugar_beet
# kippered_salmon
# gray_mullet
# sweet_roll
# julienne
# pie
# battercake
# griddlecake
# coffee_roll
# bread
# fowl
# frozen_yogurt
# haricots_verts
# scrag_end
# choc
# quince
# white_chocolate
# pullet
# fish_steak
# loose-leaf_lettuce
# guinea_hen
# leaf_mustard
# crepe
# chicken
# Fordhooks
# jellyroll
# winter_squash
# hush_puppy
# sardine
# plum_tomato
# black_cherry
# veg
# Berlin_doughnut
# broad_bean
# sea_trout
# monkfish
# granola_bar
# eggplant
# twister
# fennel
# soda_cracker
# fastnacht
# greengage_plum
# trout
# coconut_macaroon
# artichoke_heart
# watercress
# pasty
# organs
# apricot
# carp
# rugelach
# souse
# Kentucky_wonder_bean
# fortune_cookie
# Sally_Lunn
# pineapple_guava
# cornbread
# popover
# spring_onion
# poitrine_d'agneau
# Dungeness_crab
# kingfish
# surinam_cherry
# sunchoke
# takeout
# rabbit_food
# aguacate
# jumble
# Macoun
# schrod
# anise_cookie
# rib
# lamb_chop
# crisphead_lettuce
# baba_au_rhum
# meatloaf
# bliny
# Prima
# brownie
# cherrystone
# coco_plum
# sweet_orange
# broccoli_raab
# quail
# wild_plum
# chapatti
# side_of_pork
# periwinkle
# Japanese_plum
# mandarin_orange
# shellfish
# Spanish_onion
# cruller
# ackee
# chips
# smoked_mackerel
# sprinkles
# headcheese
# butter_cookie
# striper
# scollop
# soya_bean
# cherrystone_clam
# blood_pudding
# pork
# durian
# pickled_herring
# beet
# kippered_herring
# cayenne_pepper
# shin
# Toll_House_cookie
# natal_plum
# citrous_fruit
# cut_of_beef
# freshwater_bream
# chop_steak
# butter
# loaf_sugar
# rump_roast
# cherry
# pinwheel_roll
# beigel
# bell_pepper
# pork_sausage
# corn_muffin
# bun
# drop_scone
# alfalfa_sprout
# fillet
# Muenster
# lox
# forequarter
# lamb_roast
# julienne_vegetable
# health_food
# okra
# twice-baked_bread
# sorrel
# Spanish_mackerel
# Irish_soda_bread
# jacket_potato
# matzo
# Delmonico_steak
# clam
# jerky
# pheasant
# puffed_rice
# cos_lettuce
# ground_beef
# Camembert
# brownie_mix
# cardoon
# langouste
# red_currant
# squid
# American_cheese
# mamey
# herring
# babka
# farmer's_cheese
# quark
# cooking_chocolate
# ravioli
# short_ribs
# savoy_cabbage
# pork_belly
# grey_mullet
# red_meat
# gingerbread_man
# Jonathan
# winter_crookneck_squash
# Emmenthal
# king_salmon
# jerked_meat
# strawberry
# bell_apple
# dodger
# sugarloaf
# chorizo
# devil's_food
# tamarind
# oyster_cracker
# Mexican_black_cherry
# calf's_brain
# French_endive
# turtle_bean
# amarelle
# coffee_ring
# hubbard_squash
# pineapple
# beef
# carbonado
# Limburger
# side_of_meat
# buttercrunch
# ratafia
# dowdy
# german_pancake
# grouse
# hackberry
# haddock
# blueberry
# globe_pepper
# cohoe
# snow_pea
# mutton_chop
# soft-shell_clam
# light_bread
# celery_cabbage
# cowberry
# aubergine
# molasses_cookie
# lowbush_cranberry
# sea_bream
# freshwater_bass
# pinto_bean
# gray_sole

# %% [markdown]
# ### Задание 2
#
# Найдите 10 ближайших синсетов к синсету 'cow.n.01' (или один самый близкий).

# %% [markdown]
# Проходим по всем синсетам имен существительных и составляем из них словарь, ключами которого будут синсеты, а значениями - path_similarity этого синсета и интересующего нас cow.n.01.

# %%
dist_dict = {}
for synset in wn.all_synsets('n'):
    dist_dict[synset.name()] = wn.synset('cow.n.01').path_similarity(synset)

# %% [markdown]
# Затем сортируем словарь по убыванию (NB! не по ключам, а по значениям) и берем любое количество верхних элементов.

# %%
for element in sorted(dist_dict, key=lambda i: dist_dict[i], reverse=True)[:10]:
    print (element, dist_dict[element])
# Out:
# cow.n.01 1.0
# cattle.n.01 0.5
# springer.n.02 0.5
# heifer.n.01 0.5
# bovine.n.01 0.3333333333333333
# ox.n.01 0.3333333333333333
# stirk.n.01 0.3333333333333333
# bullock.n.02 0.3333333333333333
# bull.n.01 0.3333333333333333
# beef.n.01 0.3333333333333333

# %% [markdown]
# Самый близкий синсет можно найти иначе, без словаря. Например, так:

# %%
cow_similarity = 0.0
closest_synset = None
for synset in wn.all_synsets('n'):
    if wn.synset('cow.n.01').path_similarity(synset) > cow_similarity and synset.name() != 'cow.n.01':
        cow_similarity = wn.synset('cow.n.01').path_similarity(synset)
        closest_synset = synset
print (closest_synset.name())
# Out:
# cattle.n.01

# %% [markdown]
# Обратите внимание, что так мы получаем ровно один синсет, хотя по словарю выше видно, что ближайших к cow.n.01 синсетов на самом деле три.

# %% [markdown]
# ### Задание 3
#
# Напишите программу, которая будет позволять использовать MultiWordNet в качестве мультиязычного словаря. Пусть на вход она принимает слово на английском языке,
# а на выходе дает:
#
# - список его значений (т.е. синсетов, к которым оно относится, с определением к каждому синсету);
# - для каждого значения - варианты его перевода на любой язык, который есть в MultiWordNet (например, на французский или хорватский).

# %%
nltk.download('omw')
# Out:
# [nltk_data] Downloading package omw to
# [nltk_data]     C:\Users\ДР\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw is already up-to-date!
# True

# %%
input_word = input()
# Out:
# throw

# %%
synsets = wn.synsets(input_word)
for synset in synsets:
    print ('Synset: ', synset.name(), synset.definition())
    print ('English lemmas: ', synset.lemma_names())
    print ('French lemmas: ', synset.lemma_names('fra'))
# Out:
# Synset:  throw.n.01 the act of throwing (propelling something with a rapid movement of the arm and wrist)
# English lemmas:  ['throw']
# French lemmas:  ['jet', 'jeter']
# Synset:  throw.n.02 a single chance or instance
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.n.03 the maximum movement available to a pivoted or reciprocating piece by a cam
# English lemmas:  ['throw', 'stroke', 'cam_stroke']
# French lemmas:  ['accident_vasculaire_cérébral', 'coup', 'jet', 'jeter', 'mouvement']
# Synset:  throw.n.04 bedclothes consisting of a lightweight cloth covering (an afghan or bedspread) that is casually thrown over something
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.n.05 casting an object in order to determine an outcome randomly
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.v.01 propel through the air
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.v.02 move violently, energetically, or carelessly
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  shed.v.01 get rid of
# English lemmas:  ['shed', 'cast', 'cast_off', 'shake_off', 'throw', 'throw_off', 'throw_away', 'drop']
# French lemmas:  ['jet', 'jeter', 'précipiter', 'rejeter']
# Synset:  throw.v.04 place or put with great energy
# English lemmas:  ['throw', 'thrust']
# French lemmas:  ['jeter']
# Synset:  give.v.07 convey or communicate; of a smile, a look, a physical gesture
# English lemmas:  ['give', 'throw']
# French lemmas:  ['donner', 'jeter']
# Synset:  throw.v.06 cause to go on or to be engaged or set in operation
# English lemmas:  ['throw', 'flip', 'switch']
# French lemmas:  []
# Synset:  project.v.10 put or send forth
# English lemmas:  ['project', 'cast', 'contrive', 'throw']
# French lemmas:  ['jet', 'jeter']
# Synset:  throw.v.08 to put into a state or activity hastily, suddenly, or carelessly
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  bewilder.v.02 cause to be confused emotionally
# English lemmas:  ['bewilder', 'bemuse', 'discombobulate', 'throw']
# French lemmas:  ['abasourdir', 'brouiller', 'déconfire', 'jeter', 'troubler']
# Synset:  hurl.v.03 utter with force; utter vehemently
# English lemmas:  ['hurl', 'throw']
# French lemmas:  ['jeter', 'projeter']
# Synset:  hold.v.03 organize or be responsible for
# English lemmas:  ['hold', 'throw', 'have', 'make', 'give']
# French lemmas:  ['avoir', 'devoir', 'donner', 'être', 'faire', 'prendre', 'rendre', 'retenir', 'tenir']
# Synset:  throw.v.12 make on a potter's wheel
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.v.13 cause to fall off
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  throw.v.14 throw (a die) out onto a flat surface
# English lemmas:  ['throw']
# French lemmas:  ['jeter']
# Synset:  confuse.v.02 be confusing or perplexing to; cause to be unable to think clearly
# English lemmas:  ['confuse', 'throw', 'fox', 'befuddle', 'fuddle', 'bedevil', 'confound', 'discombobulate']
# French lemmas:  ['embrouiller', 'emmêler', 'perturber']

# %% [markdown]
# # FrameNet

# %% [markdown]
# ### Задание 4
#
# Найдите все ядерные элементы фрейма Removing.

# %%
nltk.download('framenet_v17')
# Out:
# [nltk_data] Downloading package framenet_v17 to
# [nltk_data]     C:\Users\ДР\AppData\Roaming\nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# True

# %%
from nltk.corpus import framenet as fn

# %%
removing = fn.frame('Removing')
for element in removing.FE:
    if removing.FE[element].coreType == "Core": #или: if removing['FE'][element]['coreType'] == 'Core':
        print (element)
# Out:
# Agent
# Theme
# Source
# Cause

# %% [markdown]
# ### Задание 5
#
# Найдите 5 примеров употребления лексемы take.v из фрейма Removing (с разметкой).

# %%
take = removing.lexUnit['take.v']
print (take.exemplars[:5])
# Out:
# [exemplar sentence (848036):
# [sentNo] 0
# [aPos] 101100749
#
# [LU] (1149) take.v in Removing
#
# [frame] (63) Removing
#
# [annotationSet] 2 annotation sets
#
# [POS] 32 tags
#
# [POS_tagset] BNC
#
# [GF] 3 relations
#
# [PT] 3 phrases
#
# [Sent] 1 entry
#
# [text] + [Target] + [FE]
#
# ` There are always exceptions to the rule , " he said flatly ,
#                                               --
#                                               Ag
#
# taking the laden tray from her hands and turning to go along the
# ****** -------------- --------------
#        Theme          Source
#
# terrace to the dining-room .
#
#
#  (Ag=Agent)
#
# , exemplar sentence (848037):
# [sentNo] 0
# [aPos] 36998910
#
# [LU] (1149) take.v in Removing
#
# [frame] (63) Removing
#
# [annotationSet] 2 annotation sets
#
# [POS] 14 tags
#
# [POS_tagset] BNC
#
# [GF] 3 relations
#
# [PT] 3 phrases
#
# [Sent] 1 entry
#
# [text] + [Target] + [FE]
#
# The maid took the plate from her mistress as if it were hot .
# -------- **** --------- -----------------
# Agent         Theme     Source
#
#
# , exemplar sentence (848038):
# [sentNo] 0
# [aPos] 30523611
#
# [LU] (1149) take.v in Removing
#
# [frame] (63) Removing
#
# [annotationSet] 2 annotation sets
#
# [POS] 25 tags
#
# [POS_tagset] BNC
#
# [GF] 3 relations
#
# [PT] 3 phrases
#
# [Sent] 1 entry
#
# [text] + [Target] + [FE]
#
# He was charmed by the tune and took the whole box from her while
# --                             **** ------------- --------
# Ag                                  Theme         Source
#
# he listened ; his face reflected an almost childlike absorption .
#
#
#
#
#
#
#  (Ag=Agent)
#
# , exemplar sentence (848040):
# [sentNo] 0
# [aPos] 80499932
#
# [LU] (1149) take.v in Removing
#
# [frame] (63) Removing
#
# [annotationSet] 2 annotation sets
#
# [POS] 13 tags
#
# [POS_tagset] BNC
#
# [GF] 3 relations
#
# [PT] 3 phrases
#
# [Sent] 1 entry
#
# [text] + [Target] + [FE]
#
# Pioneer European settlers used several methods to take land from
# ----------------                                  **** ---- -----
# Agent                                                  Them Sourc
#
# indigenous people .
# -----------------
# e
#  (Them=Theme)
#
# , exemplar sentence (848041):
# [sentNo] 0
# [aPos] 100900113
#
# [LU] (1149) take.v in Removing
#
# [frame] (63) Removing
#
# [annotationSet] 2 annotation sets
#
# [POS] 32 tags
#
# [POS_tagset] BNC
#
# [GF] 3 relations
#
# [PT] 3 phrases
#
# [Sent] 1 entry
#
# [text] + [Target] + [FE]
#
# She saw his eyes go to the coat fixture , and guessed that he
#
#
#
# knew the jacket hanging there belonged to Travis when he went and
#                                                       --
#                                                       Ag
#
#  took it from its hanger .
#  **** -- ---------------
#       Th Source
#  (Ag=Agent, Th=Theme)
#
# ]

# %% [markdown]
# ### Задание 6
#
# Найдите все фреймы, в которых Source входит в число ядерных элементов.

# %%
for frame in fn.frames():
    if 'Source' in frame['FE'] and frame['FE']['Source']['coreType'] == 'Core':
        print(frame.name)
# Out:
# Becoming_detached
# Being_detached
# Bringing
# Cause_fluidic_motion
# Cause_motion
# Container_focused_removing
# Correctness
# Cotheme
# Departing
# Detaching
# Emanating
# Emptying
# Excreting
# Fleeing
# Fluidic_motion
# Food_gathering
# Getting_underway
# Getting_vehicle_underway
# Intentional_traversing
# Level_of_light
# Light_movement
# Mass_motion
# Motion
# Motion_directional
# Motion_noise
# Motion_scenario
# Operate_vehicle
# Operate_vehicle_scenario
# Optical_image
# Passing
# Path_shape
# Planned_trajectory
# Quitting_a_place
# Removing
# Removing_scenario
# Ride_vehicle
# Robbery
# Self_motion
# Sensation
# Setting_out
# Smuggling
# Source_of_getting
# Source_path_goal
# Taking
# Theft
# Travel
# Traversing
# Use_vehicle
# Vehicle_departure_initial_stage
# Visiting_scenario_departing
# Visitor_departure
